# %%
import pandas as pd
import numpy as np 
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_goodreads_top100 = pd.read_csv ('files/goodreads_top100_from1980to2023_final.csv', index_col=0)

# %%
df_goodreads_top100
# Out:
#                isbn                                              title  \
# 0     9780689830594                                      Summer Story
# 1     9780375704970                               The Lake of Darkness
# 2     9780345446671                     Beyond the Blue Event Horizon
# 3     9780446403016                                  St. Peter's Fair
# 4     9780425198773                                          Twice Shy
# ...             ...                                                ...
# 4395  9781451648218  Murder Your Employer: The McMasters Guide to H...
# 4396  9781250826978                                   System Collapse
# 4397  9781496737298                                 Georgie, All Along
# 4398  9780525619994                                     Sword Catcher
# 4399  9780593239919                                Poverty, by America
#
#                        series_title series_release_number          authors  \
# 0                     Brambly Hedge                     2     Jill Barklem
# 1                               NaN                   NaN     Ruth Rendell
# 2                      Heechee Saga                     2    Frederik Pohl
# 3     Chronicles of Brother Cadfael                     4     Ellis Peters
# 4                               NaN                   NaN     Dick Francis
# ...                             ...                   ...              ...
# 4395                            NaN                   NaN    Rupert Holmes
# 4396          The Murderbot Diaries                     7     Martha Wells
# 4397                            NaN                   NaN    Kate Clayborn
# 4398                  Sword Catcher                     1  Cassandra Clare
# 4399                            NaN                   NaN  Matthew Desmond
#
#                                  publisher language  \
# 0                                 Atheneum  English
# 1               Vintage Crime/Black Lizard  English
# 2                         Ballantine Books  English
# 3                         Mysterious Press  English
# 4                       G.P. Putnam's Sons  English
# ...                                    ...      ...
# 4395  Avid Reader Press / Simon & Schuster  English
# 4396        Tor Publishing Group/Tordotcom  English
# 4397                            Kensington  English
# 4398                         Del Rey Books  English
# 4399                                 Crown  English
#
#                                             description num_pages  \
# 0     It was such a hot summer. The sky was deep blu...        32
# 1     Martin Urban is a quiet bachelor with a comfor...       210
# 2     In Book Two of the Heechee Saga, Robinette Bro...       336
# 3     A pause in the civil war offers Shrewsbury's t...       217
# 4     A computerized horse-betting system falls into...       304
# ...                                                 ...       ...
# 4395  A devilish thriller with a killer concept: The...       389
# 4396  Everyone's favorite lethal SecUnit is back.\nF...       245
# 4397  A wise and witty new novel that echoes with ti...       340
# 4398  In the vibrant city-state of Castellane, the r...       624
# 4399  The Pulitzer Prize–winning, bestselling author...       284
#
#                      format  \
# 0                 Hardcover
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Paperback
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  genres   publication_date  \
# 0     ['Picture Books', 'Childrens', 'Fiction', 'Ani...    January 1, 1980
# 1     ['Mystery', 'Fiction', 'Crime', 'Thriller', 'B...    January 1, 1980
# 2     ['Science Fiction', 'Fiction', 'Space Opera', ...    January 1, 1980
# 3     ['Mystery', 'Historical Fiction', 'Fiction', '...        May 1, 1981
# 4     ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...    January 1, 1981
# ...                                                 ...                ...
# 4395  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...  February 21, 2023
# 4396  ['Science Fiction', 'Fiction', 'Audiobook', 'A...  November 13, 2023
# 4397  ['Romance', 'Fiction', 'Contemporary', 'Contem...   January 24, 2023
# 4398  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...   October 10, 2023
# 4399  ['Nonfiction', 'Politics', 'Sociology', 'Histo...     March 21, 2023
#
#       rating_score  num_ratings  num_reviews  current_readers  want_to_read  \
# 0             4.45       1017.0         74.0              7.0         512.0
# 1             3.76       1388.0        114.0             77.0         623.0
# 2             3.95      13307.0        339.0            181.0        3961.0
# 3             4.12      10493.0        593.0           1298.0        2502.0
# 4             3.92       4188.0        174.0            162.0         642.0
# ...            ...          ...          ...              ...           ...
# 4395          3.89      20992.0       3479.0           4033.0       84900.0
# 4396          4.24      26566.0       3479.0           3609.0       36600.0
# 4397          3.82      48031.0       6590.0           3180.0       76300.0
# 4398          3.84      14991.0       3523.0           4485.0      149000.0
# 4399          4.30      28248.0       4007.0           6021.0      133000.0
#
#       price                                                url
# 0      3.49  https://www.goodreads.com/book/show/421572.Sum...
# 1      4.99  https://www.goodreads.com/book/show/83394.The_...
# 2     11.99  https://www.goodreads.com/book/show/373399.Bey...
# 3      0.00  https://www.goodreads.com/book/show/751755.St_...
# 4      8.99  https://www.goodreads.com/book/show/103250.Twi...
# ...     ...                                                ...
# 4395  12.99  https://www.goodreads.com/book/show/61272658-m...
# 4396  11.99  https://www.goodreads.com/book/show/65211701-s...
# 4397   0.00  https://www.goodreads.com/book/show/60604190-g...
# 4398  14.99  https://www.goodreads.com/book/show/36679274-s...
# 4399  13.99  https://www.goodreads.com/book/show/61358638-p...
#
# [4400 rows x 19 columns]

# %%
df_goodreads_top100.columns
# Out:
# Index(['isbn', 'title', 'series_title', 'series_release_number', 'authors',
#        'publisher', 'language', 'description', 'num_pages', 'format', 'genres',
#        'publication_date', 'rating_score', 'num_ratings', 'num_reviews',
#        'current_readers', 'want_to_read', 'price', 'url'],
#       dtype='object')

# %%
df_goodreads_top100.duplicated().sum()
# Out:
# 61

# %%
df_goodreads_top100.drop_duplicates (inplace = True)
df_goodreads_top100
# Out:
#                isbn                                              title  \
# 0     9780689830594                                      Summer Story
# 1     9780375704970                               The Lake of Darkness
# 2     9780345446671                     Beyond the Blue Event Horizon
# 3     9780446403016                                  St. Peter's Fair
# 4     9780425198773                                          Twice Shy
# ...             ...                                                ...
# 4395  9781451648218  Murder Your Employer: The McMasters Guide to H...
# 4396  9781250826978                                   System Collapse
# 4397  9781496737298                                 Georgie, All Along
# 4398  9780525619994                                     Sword Catcher
# 4399  9780593239919                                Poverty, by America
#
#                        series_title series_release_number          authors  \
# 0                     Brambly Hedge                     2     Jill Barklem
# 1                               NaN                   NaN     Ruth Rendell
# 2                      Heechee Saga                     2    Frederik Pohl
# 3     Chronicles of Brother Cadfael                     4     Ellis Peters
# 4                               NaN                   NaN     Dick Francis
# ...                             ...                   ...              ...
# 4395                            NaN                   NaN    Rupert Holmes
# 4396          The Murderbot Diaries                     7     Martha Wells
# 4397                            NaN                   NaN    Kate Clayborn
# 4398                  Sword Catcher                     1  Cassandra Clare
# 4399                            NaN                   NaN  Matthew Desmond
#
#                                  publisher language  \
# 0                                 Atheneum  English
# 1               Vintage Crime/Black Lizard  English
# 2                         Ballantine Books  English
# 3                         Mysterious Press  English
# 4                       G.P. Putnam's Sons  English
# ...                                    ...      ...
# 4395  Avid Reader Press / Simon & Schuster  English
# 4396        Tor Publishing Group/Tordotcom  English
# 4397                            Kensington  English
# 4398                         Del Rey Books  English
# 4399                                 Crown  English
#
#                                             description num_pages  \
# 0     It was such a hot summer. The sky was deep blu...        32
# 1     Martin Urban is a quiet bachelor with a comfor...       210
# 2     In Book Two of the Heechee Saga, Robinette Bro...       336
# 3     A pause in the civil war offers Shrewsbury's t...       217
# 4     A computerized horse-betting system falls into...       304
# ...                                                 ...       ...
# 4395  A devilish thriller with a killer concept: The...       389
# 4396  Everyone's favorite lethal SecUnit is back.\nF...       245
# 4397  A wise and witty new novel that echoes with ti...       340
# 4398  In the vibrant city-state of Castellane, the r...       624
# 4399  The Pulitzer Prize–winning, bestselling author...       284
#
#                      format  \
# 0                 Hardcover
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Paperback
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  genres   publication_date  \
# 0     ['Picture Books', 'Childrens', 'Fiction', 'Ani...    January 1, 1980
# 1     ['Mystery', 'Fiction', 'Crime', 'Thriller', 'B...    January 1, 1980
# 2     ['Science Fiction', 'Fiction', 'Space Opera', ...    January 1, 1980
# 3     ['Mystery', 'Historical Fiction', 'Fiction', '...        May 1, 1981
# 4     ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...    January 1, 1981
# ...                                                 ...                ...
# 4395  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...  February 21, 2023
# 4396  ['Science Fiction', 'Fiction', 'Audiobook', 'A...  November 13, 2023
# 4397  ['Romance', 'Fiction', 'Contemporary', 'Contem...   January 24, 2023
# 4398  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...   October 10, 2023
# 4399  ['Nonfiction', 'Politics', 'Sociology', 'Histo...     March 21, 2023
#
#       rating_score  num_ratings  num_reviews  current_readers  want_to_read  \
# 0             4.45       1017.0         74.0              7.0         512.0
# 1             3.76       1388.0        114.0             77.0         623.0
# 2             3.95      13307.0        339.0            181.0        3961.0
# 3             4.12      10493.0        593.0           1298.0        2502.0
# 4             3.92       4188.0        174.0            162.0         642.0
# ...            ...          ...          ...              ...           ...
# 4395          3.89      20992.0       3479.0           4033.0       84900.0
# 4396          4.24      26566.0       3479.0           3609.0       36600.0
# 4397          3.82      48031.0       6590.0           3180.0       76300.0
# 4398          3.84      14991.0       3523.0           4485.0      149000.0
# 4399          4.30      28248.0       4007.0           6021.0      133000.0
#
#       price                                                url
# 0      3.49  https://www.goodreads.com/book/show/421572.Sum...
# 1      4.99  https://www.goodreads.com/book/show/83394.The_...
# 2     11.99  https://www.goodreads.com/book/show/373399.Bey...
# 3      0.00  https://www.goodreads.com/book/show/751755.St_...
# 4      8.99  https://www.goodreads.com/book/show/103250.Twi...
# ...     ...                                                ...
# 4395  12.99  https://www.goodreads.com/book/show/61272658-m...
# 4396  11.99  https://www.goodreads.com/book/show/65211701-s...
# 4397   0.00  https://www.goodreads.com/book/show/60604190-g...
# 4398  14.99  https://www.goodreads.com/book/show/36679274-s...
# 4399  13.99  https://www.goodreads.com/book/show/61358638-p...
#
# [4339 rows x 19 columns]

# %%
df_goodreads_top100['isbn'].duplicated().sum()
# Out:
# 721

# %%
df_goodreads_top100['title'].duplicated().sum()
# Out:
# 199

# %%
df_goodreads_top100['isbn'].isna().sum()
# Out:
# 588

# %%
(df_goodreads_top100.isnull().sum() / df_goodreads_top100.shape[0]) * 100
# Out:
# isbn                     13.551510
# title                     0.000000
# series_title             48.444342
# series_release_number    48.720903
# authors                   0.000000
# publisher                 2.673427
# language                  0.576170
# description               0.046094
# num_pages                 0.483982
# format                    0.806637
# genres                    0.000000
# publication_date          0.023047
# rating_score              0.000000
# num_ratings               0.000000
# num_reviews               0.000000
# current_readers           2.396866
# want_to_read              0.875778
# price                     5.277714
# url                       0.000000
# dtype: float64

# %%
df_goodreads_top100[df_goodreads_top100 ['title'] == 'Twice Shy']
# Out:
#                isbn      title series_title series_release_number  \
# 4     9780425198773  Twice Shy          NaN                   NaN
# 171   9780425198773  Twice Shy          NaN                   NaN
# 4198  9780593085530  Twice Shy          NaN                   NaN
#
#            authors           publisher language  \
# 4     Dick Francis  G.P. Putnam's Sons  English
# 171   Dick Francis  G.P. Putnam's Sons  English
# 4198   Sarah Hogle  G.P. Putnam's Sons  English
#
#                                             description num_pages  \
# 4     A computerized horse-betting system falls into...       304
# 171   A computerized horse-betting system falls into...       304
# 4198  Can you find real love when you've always got ...       302
#
#                      format  \
# 4     Mass Market Paperback
# 171   Mass Market Paperback
# 4198              Paperback
#
#                                                  genres publication_date  \
# 4     ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...  January 1, 1981
# 171   ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...  January 1, 1981
# 4198  ['Romance', 'Contemporary', 'Contemporary Roma...    April 6, 2021
#
#       rating_score  num_ratings  num_reviews  current_readers  want_to_read  \
# 4             3.92       4188.0        174.0            162.0         642.0
# 171           3.92       4194.0        175.0            162.0         644.0
# 4198          3.68      33132.0       6056.0            856.0       62500.0
#
#       price                                                url
# 4      8.99  https://www.goodreads.com/book/show/103250.Twi...
# 171    8.99  https://www.goodreads.com/book/show/103250.Twi...
# 4198  11.99  https://www.goodreads.com/book/show/54660653-t...

# %%
df_goodreads_top100['series_title'].value_counts()
# Out:
# In Death                         17
# Chronicles of Brother Cadfael    15
# Black Dagger Brotherhood         15
# Vorkosigan Saga                  14
# Redwall                          14
#                                  ..
# Little Brother                    1
# Love Walked In                    1
# Olive Kitteridge                  1
# Wyoming                           1
# Sword Catcher                     1
# Name: series_title, Length: 1098, dtype: int64

# %%
df_goodreads_top100['series_release_number'].value_counts()
# Out:
# 1         788
# 2         429
# 3         293
# 4         153
# 5         100
#          ...
# 1-4         1
# 26,5        1
# 29,6        1
# 8,11        1
# 1,10.5      1
# Name: series_release_number, Length: 101, dtype: int64

# %%
df_goodreads_top100['language'].value_counts()
# Out:
# English               4277
# French                  14
# Spanish; Castilian      10
# German                   7
# Japanese                 2
# Dutch; Flemish           2
# Danish                   1
# Portuguese               1
# Name: language, dtype: int64

# %%
df_goodreads_top100['authors'].duplicated().sum()
# Out:
# 2433

# %%
df_goodreads_top100['publisher'].isna().sum()
# Out:
# 116

# %%
df_goodreads_top100['language'].isna().sum()
# Out:
# 25

# %%
df_goodreads_top100['language'] = df_goodreads_top100['language'].fillna("Unknown")

# %%
df_goodreads_top100['description'].isna().sum()
# Out:
# 2

# %%
df_goodreads_top100['description'] = df_goodreads_top100['description'].fillna("Unknown")

# %%
df_goodreads_top100['num_pages'].isna().sum()
# Out:
# 21

# %%
df_goodreads_top100['num_pages'] = df_goodreads_top100['num_pages'].fillna("Unknown")

# %%
df_goodreads_top100['format'].value_counts()
# Out:
# Paperback                1740
# Hardcover                1387
# Mass Market Paperback     706
# Kindle Edition            276
# ebook                     131
# Nook                       14
# Audio CD                   11
# Library Binding             8
# Board Book                  7
# Audio Cassette              5
# Board book                  5
# Trade Paperback             5
# Unknown Binding             2
# Audiobook                   2
# hardcover                   1
# paper                       1
# Slipcased Hardcover         1
# Print                       1
# Broschiert                  1
# Name: format, dtype: int64

# %%
df_goodreads_top100['format'].isna().sum()
# Out:
# 35

# %%
df_goodreads_top100['format'] = df_goodreads_top100['format'].fillna("Unknown")

# %%
df_goodreads_top100['genres'].value_counts()
# Out:
# ['Fantasy', 'Fiction', 'Young Adult', 'Childrens', 'Animals', 'Adventure', 'Middle Grade']        12
# ['Fiction', 'Young Adult', 'Childrens', 'Middle Grade', 'Fantasy', 'Mystery', 'Adventure']        11
# ['Mystery', 'Crime', 'Fiction', 'Thriller', 'Mystery Thriller', 'Suspense', 'Murder Mystery']     10
# []                                                                                                10
# ['Mystery', 'Fiction', 'Crime', 'Thriller', 'Detective', 'Mystery Thriller', 'Suspense']          10
#                                                                                                   ..
# ['Picture Books', 'Childrens', 'Fiction', 'Animals', 'Humor', 'Dogs', 'School']                    1
# ['Fiction', 'Contemporary', 'Romance', 'Chick Lit', 'Drama', 'Adult Fiction', 'Adult']             1
# ['Nonfiction', 'Law', 'History', 'True Crime', 'Environment', 'Crime', 'Science']                  1
# ['Mystery', 'Fiction', 'Cats', 'Cozy Mystery', 'Animals', 'Crime', 'Audiobook']                    1
# ['Nonfiction', 'Politics', 'Sociology', 'History', 'Economics', 'Audiobook', 'Social Justice']     1
# Name: genres, Length: 3625, dtype: int64

# %%
df_goodreads_top100[df_goodreads_top100['publication_date'].isna()]
# Out:
#                isbn         title series_title series_release_number  \
# 4087  9781838056124  The Present       VanWest                     2
#
#                authors publisher language  description num_pages     format  \
# 4087  Kenneth   Thomas       NaN  English  Old Version       200  Paperback
#
#                                                  genres publication_date  \
# 4087  ['Science Fiction', 'Fiction', 'Dystopia', 'Yo...              NaN
#
#       rating_score  num_ratings  num_reviews  current_readers  want_to_read  \
# 4087          3.62       2395.0         80.0             18.0        1995.0
#
#       price                                                url
# 4087    NaN  https://www.goodreads.com/book/show/54775299-t...

# %%
df_eliminar = df_goodreads_top100[df_goodreads_top100 ['isbn'] == '9781838056124']

# %%
df_goodreads_top100['publication_date'].value_counts()
# Out:
# January 1, 1984       58
# January 1, 1986       57
# January 1, 1990       55
# January 1, 1983       55
# January 1, 1982       52
#                       ..
# August 15, 2006        1
# September 25, 2006     1
# July 18, 2006          1
# June 27, 2006          1
# March 21, 2023         1
# Name: publication_date, Length: 1983, dtype: int64

# %%
df_goodreads_top100['publication_date'] = df_goodreads_top100['publication_date'].str.replace('Published ', '')

# %%
# Convertimos la columna 'publication_date' al formato de fecha
df_goodreads_top100['publication_date'] = pd.to_datetime(df_goodreads_top100['publication_date'])

# %%
# Creamos nuevas columnas para el mes y el año
df_goodreads_top100['publication_month'] = df_goodreads_top100['publication_date'].dt.month
df_goodreads_top100['publication_year'] = df_goodreads_top100['publication_date'].dt.year

# %%
df_goodreads_top100.head()
# Out:
#             isbn                           title  \
# 0  9780689830594                   Summer Story
# 1  9780375704970            The Lake of Darkness
# 2  9780345446671  Beyond the Blue Event Horizon
# 3  9780446403016               St. Peter's Fair
# 4  9780425198773                       Twice Shy
#
#                     series_title series_release_number        authors  \
# 0                  Brambly Hedge                     2   Jill Barklem
# 1                            NaN                   NaN   Ruth Rendell
# 2                   Heechee Saga                     2  Frederik Pohl
# 3  Chronicles of Brother Cadfael                     4   Ellis Peters
# 4                            NaN                   NaN   Dick Francis
#
#                     publisher language  \
# 0                    Atheneum  English
# 1  Vintage Crime/Black Lizard  English
# 2            Ballantine Books  English
# 3            Mysterious Press  English
# 4          G.P. Putnam's Sons  English
#
#                                          description num_pages  \
# 0  It was such a hot summer. The sky was deep blu...        32
# 1  Martin Urban is a quiet bachelor with a comfor...       210
# 2  In Book Two of the Heechee Saga, Robinette Bro...       336
# 3  A pause in the civil war offers Shrewsbury's t...       217
# 4  A computerized horse-betting system falls into...       304
#
#                   format                                             genres  \
# 0              Hardcover  ['Picture Books', 'Childrens', 'Fiction', 'Ani...
# 1              Paperback  ['Mystery', 'Fiction', 'Crime', 'Thriller', 'B...
# 2              Paperback  ['Science Fiction', 'Fiction', 'Space Opera', ...
# 3  Mass Market Paperback  ['Mystery', 'Historical Fiction', 'Fiction', '...
# 4  Mass Market Paperback  ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...
#
#   publication_date  rating_score  num_ratings  num_reviews  current_readers  \
# 0       1980-01-01          4.45       1017.0         74.0              7.0
# 1       1980-01-01          3.76       1388.0        114.0             77.0
# 2       1980-01-01          3.95      13307.0        339.0            181.0
# 3       1981-05-01          4.12      10493.0        593.0           1298.0
# 4       1981-01-01          3.92       4188.0        174.0            162.0
#
#    want_to_read  price                                                url  \
# 0         512.0   3.49  https://www.goodreads.com/book/show/421572.Sum...
# 1         623.0   4.99  https://www.goodreads.com/book/show/83394.The_...
# 2        3961.0  11.99  https://www.goodreads.com/book/show/373399.Bey...
# 3        2502.0   0.00  https://www.goodreads.com/book/show/751755.St_...
# 4         642.0   8.99  https://www.goodreads.com/book/show/103250.Twi...
#
#    publication_month  publication_year
# 0                1.0            1980.0
# 1                1.0            1980.0
# 2                1.0            1980.0
# 3                5.0            1981.0
# 4                1.0            1981.0

# %%
dict_meses = meses_dict = {
    1.0: 'enero',
    2.0: 'febrero',
    3.0: 'marzo',
    4.0: 'abril',
    5.0: 'mayo',
    6.0: 'junio',
    7.0: 'julio',
    8.0: 'agosto',
    9.0: 'septiembre',
    10.0: 'octubre',
    11.0: 'noviembre',
    12.0: 'diciembre'
}

# %%
df_goodreads_top100['publication_month'].map (dict_meses)
# Out:
# 0           enero
# 1           enero
# 2           enero
# 3            mayo
# 4           enero
#           ...
# 4395      febrero
# 4396    noviembre
# 4397        enero
# 4398      octubre
# 4399        marzo
# Name: publication_month, Length: 4339, dtype: object

# %%
df_goodreads_top100['publication_date'] = df_goodreads_top100['publication_date'].fillna(1.0)

# %%
df_goodreads_top100['publication_year'].astype (int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_267327/1581334872.py in <module>
# ----> 1 df_goodreads_top100['publication_year'].astype (int)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1211     """
#    1212     if not np.isfinite(values).all():
# -> 1213         raise IntCastingNaNError(
#    1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df_goodreads_top100['publication_date'] = df_goodreads_top100['publication_date'].fillna("Unknown")
